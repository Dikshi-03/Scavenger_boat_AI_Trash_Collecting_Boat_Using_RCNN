# %%
# !unzip "/content/Floating Waste.v10i.coco (1).zip" -d /content/floating_waste
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/floating_waste/train/741_jpg.rf.fe717c7dd7d122f116a2cbbfb503dcd4.jpg
#  extracting: /content/floating_waste/train/742_jpg.rf.578d7ba8770292c5e43715b18ac12328.jpg
#  extracting: /content/floating_waste/train/742_jpg.rf.68d9efa85b384cf0aa3cb261fcff97b0.jpg
#  extracting: /content/floating_waste/train/742_jpg.rf.dd591556823b3f569d32e705620bddbd.jpg
#  extracting: /content/floating_waste/train/743_jpg.rf.232e3bcf44ad62bbef55f2df385ad487.jpg
#  extracting: /content/floating_waste/train/743_jpg.rf.48d6dc921fd94124ad7496003f4e372b.jpg
#  extracting: /content/floating_waste/train/743_jpg.rf.8fccbc093041282cf6d6c81596d6323f.jpg
#  extracting: /content/floating_waste/train/744_jpg.rf.02018e6c7477536b681ecb9d5a3d5e3c.jpg
#  extracting: /content/floating_waste/train/744_jpg.rf.73a2d6905f9e41cfafee24941133924f.jpg
#  extracting: /content/floating_waste/train/744_jpg.rf.f29105da58197dbc2533fa202ea73cd5.jpg
#  extracting: /content/floating_waste/train/745_jpg.rf.8f671bf89dd09d8062ecc3badadafd97.jpg
#  extracting: /content/floating_waste/train/745_jpg.rf.c08838506f102b18192168c06e63d3fa.jpg
#  extracting: /content/floating_waste/train/745_jpg.rf.e8809dacc14a92d5c198ca600832eedc.jpg
#  extracting: /content/floating_waste/train/746_jpg.rf.4bfd4358c4d3c519a2cfa4cccccea60c.jpg
#  extracting: /content/floating_waste/train/746_jpg.rf.76e6f7cbb7966afb614a7bc4d1a4ebaa.jpg
#  extracting: /content/floating_waste/train/746_jpg.rf.7e37c812441517f7aed3b940cc420a9b.jpg
#  extracting: /content/floating_waste/train/747_jpg.rf.5af6c77cd010ac06923efce9c1d28c58.jpg
#  extracting: /content/floating_waste/train/747_jpg.rf.f69975020c8600604494517e45c10f59.jpg
#  extracting: /content/floating_waste/train/747_jpg.rf.f7c1370c21aef106a6b9622dd87aa668.jpg
#  extracting: /content/floating_waste/train/748_jpg.rf.14be02f0339c712f81c3c7f017fbbf02.jpg
#  extracting: /content/floating_waste/train/748_jpg.rf.97f1ac49802a87e15c41ec9f689e2d43.jpg
#  extracting: /content/floating_waste/train/748_jpg.rf.ba695e5d680d0ee760ec40bb9ba0fbf6.jpg
#  extracting: /content/floating_waste/train/74_jpg.rf.d6b92ee40789591cf2a9e73678c76725.jpg
#  extracting: /content/floating_waste/train/74_jpg.rf.d880e86adfdba28247710ba3b0cd4cd8.jpg
#  extracting: /content/floating_waste/train/74_jpg.rf.fdd2739a9dc4d9a1e65d4ae82c04957e.jpg
#  extracting: /content/floating_waste/train/751_jpg.rf.2716f70257c7d00a3331753e5a1c8449.jpg
#  extracting: /content/floating_waste/train/751_jpg.rf.60dcc4768b540be22c94d11abf6f82e9.jpg
#  extracting: /content/floating_waste/train/751_jpg.rf.b5f4558a9e130c7efb229aecb601c75d.jpg
#  extracting: /content/floating_waste/train/752_jpg.rf.3c98c790f8eddce1c81af67df92c19f2.jpg
#  extracting: /content/floating_waste/train/752_jpg.rf.81cf3ef0bed972d11682375bc0eb3693.jpg
#  extracting: /content/floating_waste/train/752_jpg.rf.b6a9b59524a4730b1716c26ade02aaa7.jpg
#  extracting: /content/floating_waste/train/754_jpg.rf.17eae9fe69fadf935d00c0dcb17b0e53.jpg
#  extracting: /content/floating_waste/train/754_jpg.rf.1aead08774abee6edabf5d624649e81d.jpg
#  extracting: /content/floating_waste/train/754_jpg.rf.2499d0b965fcc68968b72185143e0065.jpg
#  extracting: /content/floating_waste/train/755_jpg.rf.58851441b15a1065ec2731e5437d4830.jpg
#  extracting: /content/floating_waste/train/755_jpg.rf.6156ea49fd28533cd2def337daecdf35.jpg
#  extracting: /content/floating_waste/train/755_jpg.rf.a94c668e9d9eac8ebdd31adde929b5d8.jpg
#  extracting: /content/floating_waste/train/756_jpg.rf.7362368871416a065e8e14e1fa612d00.jpg
#  extracting: /content/floating_waste/train/756_jpg.rf.9732485e323282aac50700099bfe05e4.jpg
#  extracting: /content/floating_waste/train/756_jpg.rf.b8db56ad915bc09660bbbbe46135e918.jpg
#  extracting: /content/floating_waste/train/757_jpg.rf.0252d4e72b791dec3120abd5e67c771f.jpg
#  extracting: /content/floating_waste/train/757_jpg.rf.4210201decaf84ffa1a3c72f84384673.jpg
#  extracting: /content/floating_waste/train/757_jpg.rf.cb16f005e8014bcac2d867c5719375e0.jpg
#  extracting: /content/floating_waste/train/759_jpg.rf.4973ab3eedd42410d49c102648490561.jpg
#  extracting: /content/floating_waste/train/759_jpg.rf.6724ec2896efa7a6c24b830849eb4ba1.jpg
#  extracting: /content/floating_waste/train/759_jpg.rf.a16d0c4f248e310243c94da01f14db45.jpg
#  extracting: /content/floating_waste/train/75_jpg.rf.2218faa240e29afd249c95f85a120b62.jpg
#  extracting: /content/floating_waste/train/75_jpg.rf.45b69921c2c3f41a18264defcf59374a.jpg
#  extracting: /content/floating_waste/train/75_jpg.rf.a478cc3216ac713a03eb2c56d70a940c.jpg
#  extracting: /content/floating_waste/train/760_jpg.rf.5cd17b67a1c531f9310eaa248ae8ca93.jpg
#  extracting: /content/floating_waste/train/760_jpg.rf.76c2b656f4ec208ad7cd9193d15e1c7d.jpg
#  extracting: /content/floating_waste/train/760_jpg.rf.78d5e879949546cd678c8e28af5a126a.jpg
#  extracting: /content/floating_waste/train/763_jpg.rf.5fa9ff6fcba3f3ce3f0c97b0533dc56e.jpg
#  extracting: /content/floating_waste/train/763_jpg.rf.7018dee006e0901963d9ed6184ea17e9.jpg
#  extracting: /content/floating_waste/train/763_jpg.rf.fd6acaf327834851245066303c156e47.jpg
#  extracting: /content/floating_waste/train/764_jpg.rf.85798c30c9390e8614b837dcaa37b3f0.jpg
#  extracting: /content/floating_waste/train/764_jpg.rf.d6d418e9a283c1d91ec75931dd6e16b8.jpg
#  extracting: /content/floating_waste/train/764_jpg.rf.fe006e31584458255d4385babc8da0d7.jpg
#  extracting: /content/floating_waste/train/765_jpg.rf.0094245966cefba1869309b837cd1753.jpg
#  extracting: /content/floating_waste/train/765_jpg.rf.32f2c5ee87997c70d2faf2659a7d48a1.jpg
#  extracting: /content/floating_waste/train/793_jpg.rf.ceb7002abdf77a7a547752e53ab1a920.jpg
#  extracting: /content/floating_waste/train/793_jpg.rf.f571b4bfce81c54559ab9ce9acbabe6a.jpg
#  extracting: /content/floating_waste/train/796_jpg.rf.369118ad64b5d733913b925f84d982da.jpg
#  extracting: /content/floating_waste/train/796_jpg.rf.9cc40d8821f00bf08d33cf91c4990e23.jpg
#  extracting: /content/floating_waste/train/796_jpg.rf.c776339a9190304baa406a8346ece521.jpg
#  extracting: /content/floating_waste/train/799_jpg.rf.2e20d8e3f1de28764dfc06339b74ca0c.jpg
#  extracting: /content/floating_waste/train/799_jpg.rf.5f1f0f85e8e126193bf9d9e9c70c46d3.jpg
#  extracting: /content/floating_waste/train/799_jpg.rf.ae46e760c461ab411da3d98bb8587c94.jpg
#  extracting: /content/floating_waste/train/7_jpg.rf.1bcf199fe3a9fd0fdd98820ec5c0aa2f.jpg
#  extracting: /content/floating_waste/train/7_jpg.rf.a669cd71c114b10592deb1a026d57109.jpg
#  extracting: /content/floating_waste/train/7_jpg.rf.c6582c3f8f67edc0460a15cf30ef58e2.jpg
#  extracting: /content/floating_waste/train/802_jpg.rf.90160f93ad5f99eb67fd116778ec84f7.jpg
#  extracting: /content/floating_waste/train/802_jpg.rf.9c5cb6a3edbb1606c25fdadf6d5e0221.jpg
#  extracting: /content/floating_waste/train/802_jpg.rf.c5153a190413bc73484bc7c73b5b4ebc.jpg
#  extracting: /content/floating_waste/train/803_jpg.rf.580a9b787aa8b8bfd5bcdf934f73c6d1.jpg
#  extracting: /content/floating_waste/train/803_jpg.rf.7751823b7914b805a82c0955e79399b0.jpg
#  extracting: /content/floating_waste/train/803_jpg.rf.c711ae0cce7037602ad5b04e3b4b4926.jpg
#  extracting: /content/floating_waste/train/805_jpg.rf.6b9146a195b1867a36a8dd913c5ccbaf.jpg
#  extracting: /content/floating_waste/train/805_jpg.rf.76295c02cc7ed1be62c05b8c8dd4b407.jpg
#  extracting: /content/floating_waste/train/805_jpg.rf.a6fe984f754730c08133ed251515fa5f.jpg
#  extracting: /content/floating_waste/train/808_jpg.rf.7e4522b0b5ef72618a4046406d47951f.jpg
#  extracting: /content/floating_waste/train/808_jpg.rf.f32c409d96e38db454b5bbba55fcdc41.jpg
#  extracting: /content/floating_waste/train/808_jpg.rf.fd98b7563740f95ebc7c03ae58ef7b8f.jpg
#  extracting: /content/floating_waste/train/809_jpg.rf.165fc761d590304e5484f412e28b4cc9.jpg
#  extracting: /content/floating_waste/train/809_jpg.rf.512b8ecd155bd4cbd2c361daf0ce0374.jpg
#  extracting: /content/floating_waste/train/809_jpg.rf.5d07d91b8ac455e4866fd91df61a05bd.jpg
#  extracting: /content/floating_waste/train/80_jpg.rf.73c8f3f5241e9e65322a7ee25eea1453.jpg
#  extracting: /content/floating_waste/train/80_jpg.rf.c6f0f2198f2a369aaf92fbd5ca4674fc.jpg
#  extracting: /content/floating_waste/train/80_jpg.rf.e6f62979315f455944b7c086b06a23b7.jpg
#  extracting: /content/floating_waste/train/811_jpg.rf.212baf7bc672e29641a387e72fbe7a7c.jpg
#  extracting: /content/floating_waste/train/811_jpg.rf.95685d0019f2c5cd04d9dff375532924.jpg
#  extracting: /content/floating_waste/train/811_jpg.rf.d8f5a95cf56b6caae9c85699fcfa29cc.jpg
#  extracting: /content/floating_waste/train/812_jpg.rf.4a7b70d96eab43c6c50bb7275b658887.jpg
#  extracting: /content/floating_waste/train/812_jpg.rf.c013c01ea1963933e098a44fafe4362d.jpg
#  extracting: /content/floating_waste/train/812_jpg.rf.c31700cf8e8d778c6e81f4d34fb901cc.jpg
#  extracting: /content/floating_waste/train/813_jpg.rf.3ce6d517f639a11d2c5e5bac88c497c5.jpg
#  extracting: /content/floating_waste/train/813_jpg.rf.87a585235899571563ae8b11d80c8523.jpg
#  extracting: /content/floating_waste/train/813_jpg.rf.c064fbccee37e770b4db442fa0e0c21b.jpg
#  extracting: /content/floating_waste/train/814_jpg.rf.31906a91aff7be9dda686b6494e8363d.jpg
#  extracting: /content/floating_waste/train/814_jpg.rf.57bea5083126e6a24b3acf25d2662985.jpg
#  extracting: /content/floating_waste/train/814_jpg.rf.5a33d01d29c9f8c81ae7cd0a0afe0594.jpg
#  extracting: /content/floating_waste/train/816_jpg.rf.16f11cd89b5196cf0ca678a5c5c95273.jpg
#  extracting: /content/floating_waste/train/816_jpg.rf.72ae2eddd104b976dd2c4112b7501d5a.jpg
#  extracting: /content/floating_waste/train/816_jpg.rf.e36d3d348c2c913133813bb0578e13cb.jpg
#  extracting: /content/floating_waste/train/817_jpg.rf.1b62911c3b47b2d90e74ec3a478dce9b.jpg
#  extracting: /content/floating_waste/train/817_jpg.rf.2a4573e6244e0ba2fc90eaa67c16063d.jpg
#  extracting: /content/floating_waste/train/817_jpg.rf.2ce52af5879d6efa69b75e689ddbd384.jpg
#  extracting: /content/floating_waste/train/818_jpg.rf.4ec52a3816ef171a6419f2e4d2da8514.jpg
#  extracting: /content/floating_waste/train/818_jpg.rf.741b7b655492c666aac526621f923d35.jpg
#  extracting: /content/floating_waste/train/818_jpg.rf.abe690b3ac4b69c5ddf0e4e90bf8b2d5.jpg
#  extracting: /content/floating_waste/train/820_jpg.rf.479a8597eb165f2d664935aeed72534a.jpg
#  extracting: /content/floating_waste/train/820_jpg.rf.4de9529c41cc01190b492fe34fdd9c41.jpg
#  extracting: /content/floating_waste/train/820_jpg.rf.95316f6e7e133bd5f710a720b7a129aa.jpg
#  extracting: /content/floating_waste/train/821_jpg.rf.1c7708f745d7ea5240d11891939c2524.jpg
#  extracting: /content/floating_waste/train/821_jpg.rf.2114f4fc6b0b0e3f09771518ee679d7f.jpg
#  extracting: /content/floating_waste/train/821_jpg.rf.97a307ac866f74da94656b577a970369.jpg
#  extracting: /content/floating_waste/train/822_jpg.rf.8f0de7ba3ec03356ccef5b42a6b6042f.jpg
#  extracting: /content/floating_waste/train/822_jpg.rf.cc6b4c582a7c97342c204c9791ca7056.jpg
#  extracting: /content/floating_waste/train/822_jpg.rf.fb0ec49842fbd5277620c3f2e61ef8fd.jpg
#  extracting: /content/floating_waste/train/823_jpg.rf.06b2b4962a3a3795936a99951449a1fd.jpg
#  extracting: /content/floating_waste/train/835_jpg.rf.c1bbf5d80eb0800ee368195f7f39eac6.jpg
#  extracting: /content/floating_waste/train/835_jpg.rf.c8dcee19022c8c887c22661a3fd99859.jpg
#  extracting: /content/floating_waste/train/836_jpg.rf.c9574550fd3ae5d1b7e9fe697edfda68.jpg
#  extracting: /content/floating_waste/train/836_jpg.rf.e75ce5b7019ece0b13db9319c6652b87.jpg
#  extracting: /content/floating_waste/train/836_jpg.rf.f90a76b7dcbde16500662a7456e51d8b.jpg
#  extracting: /content/floating_waste/train/838_jpg.rf.a6aa0f8d82a005958aa4fa9372e80c4b.jpg
#  extracting: /content/floating_waste/train/838_jpg.rf.c70a3e531c715737d53a5dfa6b26e9b4.jpg
#  extracting: /content/floating_waste/train/838_jpg.rf.ce905455a5a6028daa283e401238ce76.jpg
#  extracting: /content/floating_waste/train/839_jpg.rf.0359bbe3a7ce5a2d7876bd8a60b4f06f.jpg
#  extracting: /content/floating_waste/train/839_jpg.rf.4571f7a2c15e568a9149c799d4b67ba0.jpg
#  extracting: /content/floating_waste/train/839_jpg.rf.6e10580b26ad961fb6da673d4dbe91ff.jpg
#  extracting: /content/floating_waste/train/83_jpg.rf.0480d0fc29e4e96d08764fd445f65884.jpg
#  extracting: /content/floating_waste/train/83_jpg.rf.084fb924b7e41ebaf8da871f1ce4183b.jpg
#  extracting: /content/floating_waste/train/83_jpg.rf.6674efb61fd199009f851b6dbbec7607.jpg
#  extracting: /content/floating_waste/train/840_jpg.rf.2e2a66c0ea6dcc772b6518b1dad60dd6.jpg
#  extracting: /content/floating_waste/train/840_jpg.rf.8685abbe89b9d85c8b3952a1b50b89ea.jpg
#  extracting: /content/floating_waste/train/840_jpg.rf.d6588c16c23fbe6ec6582c3ed09cc41d.jpg
#  extracting: /content/floating_waste/train/841_jpg.rf.25eada9e2e2f7edbca42236a3c939268.jpg
#  extracting: /content/floating_waste/train/841_jpg.rf.4ebd15a25fb78db6d9f327f58bede1df.jpg
#  extracting: /content/floating_waste/train/841_jpg.rf.76ba26dd6b03c7d1b598640e538f6941.jpg
#  extracting: /content/floating_waste/train/843_jpg.rf.5a449621066e0027ec586ccc27f272b2.jpg
#  extracting: /content/floating_waste/train/843_jpg.rf.76e0023c53bfea5de4f8c66721d2c6a3.jpg
#  extracting: /content/floating_waste/train/843_jpg.rf.a839ba0eddae34901c1f36e407fdda40.jpg
#  extracting: /content/floating_waste/train/844_jpg.rf.57b466cac4209f45e42365a838597a7e.jpg
#  extracting: /content/floating_waste/train/844_jpg.rf.e60e44a39990deeec2c306e9d62346eb.jpg
#  extracting: /content/floating_waste/train/844_jpg.rf.ec40b7605ee95ce80ba961f8ef0cb4d0.jpg
#  extracting: /content/floating_waste/train/845_jpg.rf.92f1c19872cd655c0312072aaec87d27.jpg
#  extracting: /content/floating_waste/train/845_jpg.rf.9b490d08b91c6afa3b78dc29f6e2c53d.jpg
#  extracting: /content/floating_waste/train/845_jpg.rf.aa25d5273748ffaf2b3f471792fe337e.jpg
#  extracting: /content/floating_waste/train/847_jpg.rf.079f94a6fd473bc39079f7368926cf2f.jpg
#  extracting: /content/floating_waste/train/847_jpg.rf.a4efe63c2b0b4a347063e75ac0d3cb4e.jpg
#  extracting: /content/floating_waste/train/847_jpg.rf.b52c7b8d24f9e283a8b263be468a451c.jpg
#  extracting: /content/floating_waste/train/849_jpg.rf.0fb82f1098cfc3b01dceeb6ac42acd5d.jpg
#  extracting: /content/floating_waste/train/849_jpg.rf.60123872711c64f515b8d34130812b43.jpg
#  extracting: /content/floating_waste/train/849_jpg.rf.b1a47a47582bbac6b606e4ceaa8ba608.jpg
#  extracting: /content/floating_waste/train/84_jpg.rf.9a2d1a4935219707a610492987346f26.jpg
#  extracting: /content/floating_waste/train/84_jpg.rf.d28c67ea6abfa8b77b3805ca51661b90.jpg
#  extracting: /content/floating_waste/train/84_jpg.rf.ea212f5e2f04387f1634e6a74807b2b6.jpg
#  extracting: /content/floating_waste/train/850_jpg.rf.abc416ef22cb32021ec15de5e7e9fc7f.jpg
#  extracting: /content/floating_waste/train/850_jpg.rf.b3a41d8ba5d8765d2ee1b649f41e3f2a.jpg
#  extracting: /content/floating_waste/train/850_jpg.rf.b5984a24a3aebfbcefd46c32339a815d.jpg
#  extracting: /content/floating_waste/train/851_jpg.rf.2a212987855b0968be8fe4880b7fe5dc.jpg
#  extracting: /content/floating_waste/train/851_jpg.rf.9eeafb021055943707cf04b9c77a85c4.jpg
#  extracting: /content/floating_waste/train/851_jpg.rf.f4e4c22bd26ee7eeb59af5552aeedd0e.jpg
#  extracting: /content/floating_waste/train/856_jpg.rf.0c2138d7967fb7c3253309968ece801e.jpg
#  extracting: /content/floating_waste/train/856_jpg.rf.33cf4cfc4f5a598c12d6ca11824a518a.jpg
#  extracting: /content/floating_waste/train/856_jpg.rf.d230305420add62ef352b498cb9feaeb.jpg
#  extracting: /content/floating_waste/train/858_jpg.rf.3f16c91b2b0e9492d6be18f7facf828c.jpg
#  extracting: /content/floating_waste/train/858_jpg.rf.65a8b03903d9c8885538c1d88f470229.jpg
#  extracting: /content/floating_waste/train/858_jpg.rf.fff2fc318571072f143f680396ee5d94.jpg
#  extracting: /content/floating_waste/train/859_jpg.rf.3bd69618b525d8e6a2af4b554b4e5ecd.jpg
#  extracting: /content/floating_waste/train/859_jpg.rf.aa71f97c81bb60599dca669c5158fd3f.jpg
#  extracting: /content/floating_waste/train/859_jpg.rf.ee342c3960525d9fb4545fe6e827e040.jpg
#  extracting: /content/floating_waste/train/860_jpg.rf.2103930b9cce5941df8519dd0cfd01e5.jpg
#  extracting: /content/floating_waste/train/860_jpg.rf.4b667050b5a42f8d663ef5d9df6a7dcd.jpg
#  extracting: /content/floating_waste/train/860_jpg.rf.5d8d5dcf125d9e2a5b43ce43282dd137.jpg
#  extracting: /content/floating_waste/train/861_jpg.rf.44bf955ba8865d4ba3fc223bba1ea284.jpg
#  extracting: /content/floating_waste/train/861_jpg.rf.900d03cdc825ee217bbee0d9f42954cf.jpg
#  extracting: /content/floating_waste/train/861_jpg.rf.b5c02435b0d567b1ca111ab997c39adc.jpg
#  extracting: /content/floating_waste/train/875_jpg.rf.1a9473e801301cab20bde7ecbb9c65ae.jpg
#  extracting: /content/floating_waste/train/875_jpg.rf.e16735f5dac6ef70ae7e23efa77ad380.jpg
#  extracting: /content/floating_waste/train/876_jpg.rf.6170e6bcb47021fbf41296ede646bc5b.jpg
#  extracting: /content/floating_waste/train/876_jpg.rf.a0d6b3cf1ff9e983798c7f4ad606a464.jpg
#  extracting: /content/floating_waste/train/876_jpg.rf.f9ae41b2c5455a62a1963be222057168.jpg
#  extracting: /content/floating_waste/train/878_jpg.rf.9756dffaf26cc587fa8f18a71c48c116.jpg
#  extracting: /content/floating_waste/train/878_jpg.rf.f09e3dfe9538ab79e9948fb8b2bc46f9.jpg
#  extracting: /content/floating_waste/train/878_jpg.rf.fda8c432897e5ffec3607e8ea702e534.jpg
#  extracting: /content/floating_waste/train/87_jpg.rf.48582d5e01cd189a3e7742172dd76fe7.jpg
#  extracting: /content/floating_waste/train/87_jpg.rf.5e6754a8db158a12883dfc38e52bbc30.jpg
#  extracting: /content/floating_waste/train/87_jpg.rf.c60fdebd716855099e29dee959c25abd.jpg
#  extracting: /content/floating_waste/train/880_jpg.rf.584093e2aade25675ed1f4886b57b4d8.jpg
#  extracting: /content/floating_waste/train/880_jpg.rf.8a651548e24ee17af2db8f49c51ca484.jpg
#  extracting: /content/floating_waste/train/880_jpg.rf.ecfacb8666a3a74755b6950fd909d01e.jpg
#  extracting: /content/floating_waste/train/882_jpg.rf.6705dba05d30e666d8baf42e20dee14d.jpg
#  extracting: /content/floating_waste/train/882_jpg.rf.c5133f59c5ed44e7db5a364a61894a59.jpg
#  extracting: /content/floating_waste/train/882_jpg.rf.dd55549e99fb2bcbf7542dcb42903c5e.jpg
#  extracting: /content/floating_waste/train/883_jpg.rf.68b51a71e628ece67749d0225a5924e4.jpg
#  extracting: /content/floating_waste/train/883_jpg.rf.9c0e84f20f186e7b58b4f5c26ca36b77.jpg
#  extracting: /content/floating_waste/train/883_jpg.rf.fad44b09a71e3ff00fe3390bfdea4c0e.jpg
#  extracting: /content/floating_waste/train/884_jpg.rf.2555e7b16af15e1ecc2bd35bee8f890c.jpg
#  extracting: /content/floating_waste/train/884_jpg.rf.a980a654248160a99832864e13ef1b74.jpg
#  extracting: /content/floating_waste/train/884_jpg.rf.c130496ca270358f9f900e1472b580d0.jpg
#  extracting: /content/floating_waste/train/889_jpg.rf.5e480ff1ca2e9095dcc236df0e152603.jpg
#  extracting: /content/floating_waste/train/889_jpg.rf.90e493543aecb12ce518982db7a06673.jpg
#  extracting: /content/floating_waste/train/889_jpg.rf.be178df27e39a6c3160a817d5ff29fd0.jpg
#  extracting: /content/floating_waste/train/88_jpg.rf.1d92299edf9056c856c03d367105e84e.jpg
#  extracting: /content/floating_waste/train/88_jpg.rf.c0cd2ce6971e785debbcf470a5025aa5.jpg
#  extracting: /content/floating_waste/train/88_jpg.rf.ed6cd970c8e577534ac1d81cad829f5d.jpg
#  extracting: /content/floating_waste/train/890_jpg.rf.81b0a63220f93cc2b0c9a73a8db5a477.jpg
#  extracting: /content/floating_waste/valid/frame_009_jpg.rf.232a48eb84cbfceed2099d70f3cad081.jpg
#  extracting: /content/floating_waste/valid/frame_009_jpg.rf.2d96387070a4cbff5e7d769969ead8e0.jpg
#  extracting: /content/floating_waste/valid/frame_010_jpg.rf.5b788bdeb569be0df1bc9c58865ccf8a.jpg
#  extracting: /content/floating_waste/valid/frame_011_jpg.rf.11d95929c86b9bf33fa35c2998cc5ddd.jpg
#  extracting: /content/floating_waste/valid/frame_012_jpg.rf.c635226e84e1103077018fe3c3ad9163.jpg
#  extracting: /content/floating_waste/valid/frame_013_jpg.rf.282290375dab3560457d420f6bbaeed6.jpg
#  extracting: /content/floating_waste/valid/frame_013_jpg.rf.63327499f0484c185fd9601c2d723d48.jpg
#  extracting: /content/floating_waste/valid/frame_015_jpg.rf.abce43f63d54a30ae99eda6575b94a23.jpg
#  extracting: /content/floating_waste/valid/frame_018_jpg.rf.55d15f9b3052c48a0e4a85ba3b8ebca8.jpg
#  extracting: /content/floating_waste/valid/frame_019_jpg.rf.dc5c8f5e1b641312f6bc12e9a5e7e325.jpg
#  extracting: /content/floating_waste/valid/frame_020_jpg.rf.1f39828af8c1ef2c7f37c3bd00a9fcc4.jpg
#  extracting: /content/floating_waste/valid/frame_022_jpg.rf.5f984091e76f621bc0132662631a76fe.jpg
#  extracting: /content/floating_waste/valid/frame_025_jpg.rf.42ec1890aa5a96f6beb627dba4010169.jpg
#  extracting: /content/floating_waste/valid/frame_026_jpg.rf.c3e671c462205d010929842673b1d86d.jpg
#  extracting: /content/floating_waste/valid/frame_029_jpg.rf.6a6c9825b4bc204dbb24ba71bb34193f.jpg
#  extracting: /content/floating_waste/valid/frame_030_jpg.rf.bc218e511d882770dc7705d8b7acc5c4.jpg
#  extracting: /content/floating_waste/valid/frame_030_jpg.rf.edeff638296311928c67b663dd6f58d6.jpg
#  extracting: /content/floating_waste/valid/frame_034_jpg.rf.9905ed181ae588eb78dd9e00091fcd9e.jpg
#  extracting: /content/floating_waste/valid/frame_035_jpg.rf.ce0d448690c7b05dd8a7069f072575a9.jpg
#  extracting: /content/floating_waste/valid/frame_036_jpg.rf.65a517a27f355f6baf08b343c6f9ef9d.jpg
#  extracting: /content/floating_waste/valid/frame_038_jpg.rf.04bc10d68b584de621ebe4f3e78dfb89.jpg
#  extracting: /content/floating_waste/valid/frame_049_jpg.rf.fad1e8a0bf807b3940f8a3594e092bc2.jpg
#  extracting: /content/floating_waste/valid/frame_050_jpg.rf.282a95fbc84799db79e43ff843da145e.jpg
#  extracting: /content/floating_waste/valid/frame_067_jpg.rf.c0e7dd022816485ba7981eee65d63ae1.jpg
#  extracting: /content/floating_waste/valid/frame_071_jpg.rf.eac9c81dcf63d47f87794e8cd7bdaa45.jpg
#  extracting: /content/floating_waste/valid/frame_077_jpg.rf.174d5b02be44a741a1f507745d640fd2.jpg
#  extracting: /content/floating_waste/valid/frame_079_jpg.rf.d0a50dabecfefe6ee598b35ef5224945.jpg
#  extracting: /content/floating_waste/valid/frame_081_jpg.rf.a565ba6ec140daf923bb8f587e79768d.jpg

# %%
import os
import json
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import functional as F
from PIL import Image
from torchvision.models.detection import fasterrcnn_mobilenet_v3_large_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from tqdm import tqdm

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# COCO-style dataset loader
class COCODataset(Dataset):
    def __init__(self, image_dir, annotation_path):
        self.image_dir = image_dir
        with open(annotation_path, 'r') as f:
            coco = json.load(f)

        self.images = {img['id']: img['file_name'] for img in coco['images']}
        self.annotations = {}
        for ann in coco['annotations']:
            img_id = ann['image_id']
            bbox = ann['bbox']  # [x, y, width, height]
            label = ann['category_id']
            if img_id not in self.annotations:
                self.annotations[img_id] = []
            self.annotations[img_id].append({"bbox": bbox, "label": label})

        # Filter only existing images
        self.ids = [img_id for img_id in self.images if os.path.exists(os.path.join(self.image_dir, self.images[img_id]))]
        missing = set(self.images.keys()) - set(self.ids)
        if missing:
            print(f"[Warning] {len(missing)} images referenced in annotations not found in '{self.image_dir}' and will be skipped.")

        self.class_to_idx = {cat['id']: cat['name'] for cat in coco['categories']}

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        img_id = self.ids[idx]
        img_path = os.path.join(self.image_dir, self.images[img_id])

        try:
            img = Image.open(img_path).convert("RGB")
        except FileNotFoundError:
            return None

        annots = self.annotations.get(img_id, [])
        boxes = []
        labels = []
        for ann in annots:
            x, y, w, h = ann['bbox']
            boxes.append(torch.tensor([x, y, x + w, y + h], dtype=torch.float32))
            labels.append(ann['label'])

        if not boxes:
            return None

        target = {
            "boxes": torch.stack(boxes),
            "labels": torch.tensor(labels, dtype=torch.int64),
            "image_id": torch.tensor([idx])
        }

        return F.to_tensor(img), target

# Collate function
def collate_fn(batch):
    batch = list(filter(lambda x: x is not None, batch))
    return tuple(zip(*batch)) if batch else ([], [])

# Dataset paths
image_dir = "/content/floating_waste/train"
annotation_file = "/content/floating_waste/train/_annotations.coco.json"

# Load dataset
train_dataset = COCODataset(image_dir, annotation_file)
if len(train_dataset) == 0:
    raise ValueError("No valid training samples found. Please verify your dataset paths and annotations.")
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# Load model (MobileNet backbone for smaller & faster model)
model = fasterrcnn_mobilenet_v3_large_fpn(weights="DEFAULT")

# Replace the head
num_classes = len(set(train_dataset.class_to_idx.keys())) + 1  # background + classes
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
model.to(device)

# Optimizer & scaler
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
scaler = torch.amp.GradScaler(device="cuda" if torch.cuda.is_available() else "cpu")
use_amp = torch.cuda.is_available()

# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    print(f"\nEpoch [{epoch+1}/{num_epochs}]")
    loop = tqdm(train_loader, desc="Training", unit="batch")

    for i, batch in enumerate(loop):
        if not batch[0]:
            continue

        images, targets = batch
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        with torch.amp.autocast(device_type=device.type, enabled=use_amp):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        scaler.scale(losses).backward()
        scaler.step(optimizer)
        scaler.update()

        batch_loss = losses.item()
        running_loss += batch_loss

        loop.set_postfix(batch_loss=batch_loss)

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}] Avg Loss: {avg_loss:.4f}")

print("\nTraining complete.")
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth
# 100%|██████████| 74.2M/74.2M [00:00<00:00, 150MB/s]
# Epoch [1/10]
# Training: 100%|██████████| 1672/1672 [04:39<00:00,  5.98batch/s, batch_loss=0.206]
# Epoch [1/10] Avg Loss: 0.3125
#
# Epoch [2/10]
# Training: 100%|██████████| 1672/1672 [04:29<00:00,  6.20batch/s, batch_loss=0.281]
# Epoch [2/10] Avg Loss: 0.3408
#
# Epoch [3/10]
# Training: 100%|██████████| 1672/1672 [04:26<00:00,  6.28batch/s, batch_loss=0.219]
# Epoch [3/10] Avg Loss: 0.3548
#
# Epoch [4/10]
# Training: 100%|██████████| 1672/1672 [04:25<00:00,  6.29batch/s, batch_loss=0.51]
# Epoch [4/10] Avg Loss: 0.3655
#
# Epoch [5/10]
# Training: 100%|██████████| 1672/1672 [04:24<00:00,  6.32batch/s, batch_loss=0.537]
# Epoch [5/10] Avg Loss: 0.3767
#
# Epoch [6/10]
# Training: 100%|██████████| 1672/1672 [04:23<00:00,  6.35batch/s, batch_loss=0.454]
# Epoch [6/10] Avg Loss: 0.3774
#
# Epoch [7/10]
# Training: 100%|██████████| 1672/1672 [04:24<00:00,  6.33batch/s, batch_loss=0.258]
# Epoch [7/10] Avg Loss: 0.3758
#
# Epoch [8/10]
# Training: 100%|██████████| 1672/1672 [04:24<00:00,  6.33batch/s, batch_loss=0.25]
# Epoch [8/10] Avg Loss: 0.3836
#
# Epoch [9/10]
# Training: 100%|██████████| 1672/1672 [04:24<00:00,  6.32batch/s, batch_loss=0.165]
# Epoch [9/10] Avg Loss: 0.3798
#
# Epoch [10/10]
# Training: 100%|██████████| 1672/1672 [04:24<00:00,  6.33batch/s, batch_loss=0.12]
# Epoch [10/10] Avg Loss: 0.3776
#
# Training complete.

# %%
import json

# Path to your COCO annotation file
annotation_path = "/content/floating_waste/train/_annotations.coco.json"

# Load the category names from the COCO JSON
with open(annotation_path) as f:
    coco_json = json.load(f)
    classes = coco_json['categories']  # This is a list of dicts like: [{'id': 1, 'name': 'bottle'}, ...]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import torchvision.transforms as T

def predict_image(image_path, model, classes, threshold=0.5):
    model.eval()
    image = Image.open(image_path).convert("RGB")
    transform = T.ToTensor()
    img_tensor = transform(image).to(device)

    with torch.no_grad():
        prediction = model([img_tensor])[0]

    img_np = np.array(image)

    for box, label, score in zip(prediction['boxes'], prediction['labels'], prediction['scores']):
        if score >= threshold:
            x1, y1, x2, y2 = box.int().cpu().numpy()
            class_name = classes[label.item() - 1]['name']
            img_np = cv2.rectangle(img_np, (x1, y1), (x2, y2), (0, 255, 0), 2)
            img_np = cv2.putText(img_np, f"{class_name}: {score:.2f}", (x1, y1-10),
                                 cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    plt.figure(figsize=(10, 8))
    plt.imshow(img_np)
    plt.axis("off")
    plt.show()

# Example usage
predict_image("/content/floating_waste/valid/frame_000429_jpg.rf.63f26366e51722f747603d893898b0e3.jpg", model, classes)

# %%
torch.save(model.state_dict(), "fasterrcnn_floating_trash_new1.pth")

# %%
import torch
from torchvision.models.detection import fasterrcnn_mobilenet_v3_large_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.datasets import CocoDetection
from torchvision import transforms
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import json
from tqdm import tqdm

# ------------------
# Paths
# ------------------
VAL_IMAGES_DIR = "/content/floating_waste/valid"
VAL_ANN_FILE = "/content/floating_waste/valid/_annotations.coco.json"
MODEL_PATH = "/content/fasterrcnn_floating_trash_new1.pth"  # your checkpoint
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ------------------
# Auto-detect number of classes from COCO JSON
# ------------------
with open(VAL_ANN_FILE, "r") as f:
    coco_json = json.load(f)
NUM_CLASSES = len(coco_json["categories"]) + 1  # +1 for background
print(f"Detected {NUM_CLASSES - 1} classes + background")

# ------------------
# Dataset & Loader
# ------------------
transform = transforms.Compose([transforms.ToTensor()])
dataset = CocoDetection(root=VAL_IMAGES_DIR, annFile=VAL_ANN_FILE, transform=transform)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=False,
                                          collate_fn=lambda x: tuple(zip(*x)))

# ------------------
# Rebuild Model Architecture
# ------------------
print("Loading model checkpoint...")
model = fasterrcnn_mobilenet_v3_large_fpn(weights=None)
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, NUM_CLASSES)

state_dict = torch.load(MODEL_PATH, map_location=DEVICE)
model.load_state_dict(state_dict)
model.to(DEVICE)
model.eval()
print("Model loaded.")

# ------------------
# Run Inference
# ------------------
print("Running inference...")
results = []

with torch.no_grad():
    for idx, (images, targets) in enumerate(tqdm(data_loader)):
        images = [img.to(DEVICE) for img in images]
        outputs = model(images)

        for target, out in zip(targets, outputs):
            if len(target) > 0:
                image_id = int(target[0]["image_id"])
            else:
                image_id = int(dataset.ids[idx])

            boxes  = out["boxes"].cpu().numpy()
            scores = out["scores"].cpu().numpy()
            labels = out["labels"].cpu().numpy()

            for box, score, label in zip(boxes, scores, labels):
                x_min, y_min, x_max, y_max = box
                results.append({
                    "image_id": image_id,
                    "category_id": int(label),
                    "bbox": [
                        float(x_min),
                        float(y_min),
                        float(x_max - x_min),
                        float(y_max - y_min)
                    ],
                    "score": float(score)
                })

# ------------------
# Save Predictions to JSON
# ------------------
results_file = "coco_results.json"
with open(results_file, "w") as f:
    json.dump(results, f)

# ------------------
# Evaluate with COCO API
# ------------------
print("Evaluating...")
coco_gt = COCO(VAL_ANN_FILE)
coco_dt = coco_gt.loadRes(results_file)

coco_eval = COCOeval(coco_gt, coco_dt, "bbox")
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()
# Out:
# Detected 6 classes + background
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading model checkpoint...
# Model loaded.
# Running inference...
# 100%|██████████| 638/638 [00:18<00:00, 34.39it/s]
# Evaluating...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.77s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.556
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.711
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.741

# %%
import torch
from torchvision.models.detection import fasterrcnn_mobilenet_v3_large_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

trained_weights_path = "/content/fasterrcnn_floating_trash_new1.pth"
num_classes_new = 6  # 6 classes, no background in your label indexing

# Initialize model architecture without pretrained weights
model = fasterrcnn_mobilenet_v3_large_fpn(weights=None, weights_backbone=None)

# Load full checkpoint state dict
checkpoint = torch.load(trained_weights_path, map_location=torch.device('cpu'))

# Remove classification head params from checkpoint dict to avoid size mismatch
checkpoint_filtered = {k: v for k, v in checkpoint.items()
                       if not k.startswith("roi_heads.box_predictor.")}

# Load filtered checkpoint into model
model.load_state_dict(checkpoint_filtered, strict=False)

# Replace the box predictor with a new one for your number of classes
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes_new)

model.eval()

# Quantize dynamically
quantized_model = torch.quantization.quantize_dynamic(
    model, {torch.nn.Linear, torch.nn.Conv2d}, dtype=torch.qint8
)

# Convert to TorchScript
scripted_model = torch.jit.script(quantized_model)

# Save scripted model
scripted_model.save("scripted_quantized_mobilenet_frcnn_new1.pt")

print("MobileNetV3-FPN model loaded, old head removed, quantized, scripted, and saved successfully!")
# Out:
# MobileNetV3-FPN model loaded, old head removed, quantized, scripted, and saved successfully!

# %%
import torch
import json
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms as T

# ------------------ Paths ------------------
MODEL_PATH = "/content/scripted_quantized_mobilenet_frcnn_new1.pt"
VAL_ANN_FILE = "/content/floating_waste/valid/_annotations.coco.json"
IMAGE_PATH = "/content/floating_waste/valid/frame_000429_jpg.rf.63f26366e51722f747603d893898b0e3.jpg"  # test image

# ------------------ Device ------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ------------------ Load TorchScript model ------------------
print("Loading TorchScript model...")
model = torch.jit.load(MODEL_PATH, map_location=device)
model.eval()
model.to(device)
print("Model loaded.")

# ------------------ Load classes from COCO JSON ------------------
with open(VAL_ANN_FILE, "r") as f:
    coco_json = json.load(f)

# Map category id -> class name
classes = {cat["id"]: cat["name"] for cat in coco_json["categories"]}
print(f"Detected classes: {classes}")

# ------------------ Prediction & Visualization Function ------------------
def predict_image(image_path, model, classes, threshold=0.5):
    # Load image
    image = Image.open(image_path).convert("RGB")
    img_tensor = T.ToTensor()(image).to(device)

    # Run inference
    with torch.no_grad():
        output = model([img_tensor])
        # TorchScript Faster R-CNN may return tuple: (losses, detections)
        if isinstance(output, tuple) and len(output) == 2:
            _, prediction = output
            prediction = prediction[0]
        else:
            prediction = output[0]

    # Convert to NumPy for visualization
    img_np = np.array(image)

    # Draw boxes and labels
    for box, label, score in zip(prediction['boxes'], prediction['labels'], prediction['scores']):
        if score >= threshold:
            x1, y1, x2, y2 = box.int().cpu().numpy()
            class_name = classes[label.item()]
            img_np = cv2.rectangle(img_np, (x1, y1), (x2, y2), (0, 255, 0), 2)
            img_np = cv2.putText(img_np, f"{class_name}: {score:.2f}", (x1, y1-10),
                                 cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Display image
    plt.figure(figsize=(12, 10))
    plt.imshow(img_np)
    plt.axis("off")
    plt.show()

# ------------------ Run on Example Image ------------------
predict_image(IMAGE_PATH, model, classes, threshold=0.5)

# %%
import torch
from PIL import Image
from torchvision.transforms import functional as F

# Load the scripted quantized model
model = torch.jit.load("scripted_quantized_mobilenet_frcnn_new1.pt")
model.eval()

# Load an image
image_path = "path_to_your_image.jpg"
img = Image.open(image_path).convert("RGB")
img_tensor = F.to_tensor(img)  # Convert to [C, H, W] tensor

# Forward pass (wrap in list as model expects a batch)
with torch.no_grad():
    outputs = model([img_tensor])

# outputs is a list of dicts (one per image)
for i, output in enumerate(outputs):
    print(f"\nImage {i+1} predictions:")
    boxes = output["boxes"]
    labels = output["labels"]
    scores = output["scores"]

    for j in range(len(boxes)):
        print(f"Object {j+1}:")
        print(f"  Box: {boxes[j].tolist()}")
        print(f"  Label: {labels[j].item()}")
        print(f"  Score: {scores[j].item():.4f}")
